# %%
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_9 (Dense)             (None, 300)               235500
#
#  dense_10 (Dense)            (None, 100)               30100
#
#  dense_11 (Dense)            (None, 10)                1010
#
# ...
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model)

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.SGD(0.1), metrics=["accuracy"])

# %%
h = model.fit(X_train/255.0, y_train, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.5365 - accuracy: 0.8061 - val_loss: 0.4617 - val_accuracy: 0.8282
# Epoch 2/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3871 - accuracy: 0.8572 - val_loss: 0.5873 - val_accuracy: 0.7940
# Epoch 3/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3467 - accuracy: 0.8724 - val_loss: 0.3778 - val_accuracy: 0.8607
# Epoch 4/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3209 - accuracy: 0.8807 - val_loss: 0.3513 - val_accuracy: 0.8747
# Epoch 5/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3001 - accuracy: 0.8880 - val_loss: 0.3760 - val_accuracy: 0.8655
# Epoch 6/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2832 - accuracy: 0.8945 - val_loss: 0.3231 - val_accuracy: 0.8805
# Epoch 7/50
# ...

# %%
pd.DataFrame(h.history).plot(figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %%
model2 = keras.models.Sequential()
model2.add(keras.layers.Flatten(input_shape=[28, 28]))
model2.add(keras.layers.Dense(300, activation="relu"))
model2.add(keras.layers.Dense(100, activation="relu"))
model2.add(keras.layers.Dense(10, activation="softmax"))
model2.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.SGD(0.01), metrics=["accuracy"])
h = model2.fit(X_train/255.0, y_train, epochs=50, validation_split=0.1)
pd.DataFrame(h.history).plot(figsize=(10, 5))
# Out:
# Epoch 1/50
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.6939 - accuracy: 0.7753 - val_loss: 0.5203 - val_accuracy: 0.8138
# Epoch 2/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4824 - accuracy: 0.8326 - val_loss: 0.4627 - val_accuracy: 0.8370
# Epoch 3/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4400 - accuracy: 0.8481 - val_loss: 0.4269 - val_accuracy: 0.8462
# Epoch 4/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4118 - accuracy: 0.8571 - val_loss: 0.4147 - val_accuracy: 0.8517
# Epoch 5/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3927 - accuracy: 0.8625 - val_loss: 0.3973 - val_accuracy: 0.8575
# Epoch 6/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3762 - accuracy: 0.8675 - val_loss: 0.3862 - val_accuracy: 0.8628
# Epoch 7/50
# ...
